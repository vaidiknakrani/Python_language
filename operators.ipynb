# %% [markdown]
# <a href="https://colab.research.google.com/github/vaidiknakrani/Python_language/blob/main/operators.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#what is operator>>> special keywords to perform operations
#why? To manipualte data


#arithmatic operator
a = 5
b = 2
a+b
# Out:
# 7

# %%
add = 5+2
print(add)
# Out:
# 7

# %%
add
# Out:
# 7

# %%
5+2
# Out:
# 7

# %%
20 - 3
# Out:
# 17

# %%
3 * 4
# Out:
# 12

# %%
20 / 4
# Out:
# 5.0

# %%
#modulus operator
17 % 4
# Out:
# 1

# %%
2 ** 3 #2*2*2
# Out:
# 8

# %%
3 ** 2
# Out:
# 9

# %%
4/ 3
# Out:
# 1.3333333333333333

# %%
4 // 3 #floor operator
# Out:
# 1

# %%
a = 2

# %%
# Comparison operator >> compare two values>> return a boolean value

2 == 2
# Out:
# True

# %%
2 != 2
# Out:
# False

# %%
5 != 2
# Out:
# True

# %%
10>2
# Out:
# True

# %%
10 < 5
# Out:
# False

# %%
10 >= 10
# Out:
# True

# %%
10 >= 1
# Out:
# True

# %%
10<=10
# Out:
# True

# %%
10 <= 12
# Out:
# True

# %%
10 >= 12
# Out:
# False

# %%
#Logical operator
#and
True and True
# Out:
# True

# %%
True and False
# Out:
# False

# %%
False and True
# Out:
# False

# %%
False and False
# Out:
# False

# %%
True or False
# Out:
# True

# %%
False or True
# Out:
# True

# %%
#Not operator
not True
# Out:
# False

# %%
not False
# Out:
# True

# %%
#Assignment operator

a  =10

# %%
a
# Out:
# 10

# %%
a + 5
# Out:
# 15

# %%
a
# Out:
# 10

# %%
a = a + 10

# %%
a
# Out:
# 20

# %%
a += 5

# %%
a
# Out:
# 25

# %%
a
# Out:
# 25

# %%
a *= 2

# %%
a
# Out:
# 50

# %%
a
# Out:
# 50

# %%
a /= 3

# %%
a
# Out:
# 16.666666666666668

# %%
#membership operator

a = "PWSKILLS"

"P" in a
# Out:
# True

# %%
"am" in "I am Ajay"
# Out:
# True

# %%
"data" in "PWSKILLS"
# Out:
# False

# %%
"data" not in "PWSKILLS"
# Out:
# True

# %%
a = ["data", "science", "ajay"]

# %%
"data" in a
# Out:
# True

# %%
#identity operator >> compare the memory location of two object
a = 2

# %%
b = 3

# %%
a is b
# Out:
# False

# %%
b is a
# Out:
# False

# %%
a = "Pw Skills"
b=a

# %%
b is a
# Out:
# True

# %%
a is b
# Out:
# True

# %%
a = "pwskills"
b = "data"
a is b
# Out:
# False

# %%
a is not b
# Out:
# True

# %%
#bitwise operator>> operations at bit level
10 & 10
# Out:
# 10

# %%
18 & 3
# Out:
# 2

# %%
bin(10)
# Out:
# '0b1010'

# %%
bin(18)
# Out:
# '0b10010'

# %%
bin(3)
# Out:
# '0b11'

# %%
bin(2)
# Out:
# '0b10'

# %%
3 | 5
# Out:
# 7

# %%
bin(3)
# Out:
# '0b11'

# %%
bin(5)
# Out:
# '0b101'

# %%
#negation
~3
# Out:
# -4

# %%
~100
# Out:
# -101

# %%
~6
# Out:
# -7

# %%
#Bitwise xor >> return 1 when exactly one operand is 1

5 ^ 3
# Out:
# 6

# %%
bin(5)
# Out:
# '0b101'

# %%
bin(3)
# Out:
# '0b11'

# %%
bin(6)
# Out:
# '0b110'

# %%
#shift >> left shift and right shift

# %%
#left shift put no of zeros on right side

35 << 3
# Out:
# 280

# %%
bin(35)
# Out:
# '0b100011'

# %%
bin(280)
# Out:
# '0b100011000'

# %%
5 << 1
# Out:
# 10

# %%
bin(5)
# Out:
# '0b101'

# %%
bin(10)
# Out:
# '0b1010'

# %%
#Right shift operator >> remove the no of elements in the binary
280 >> 3
# Out:
# 35

# %%
bin(280)
# Out:
# '0b100011000'

# %%
bin(35)
# Out:
# '0b100011'

# %%
10 >> 1
# Out:
# 5

# %%
bin(10)
# Out:
# '0b1010'

# %%
bin(5)
# Out:
# '0b101'

# %%
## order of precedence
#execution will start from left
2+3-1
# Out:
# 4

# %%
#always parenthesis

(5+3) - 4
# Out:
# 4

# %%
4 - (5+3)
# Out:
# -4

# %%
(10+5) + (8/2)
# Out:
# 19.0
