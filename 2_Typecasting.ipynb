# %% [markdown]
# <a href="https://colab.research.google.com/github/vaidiknakrani/Python_language/blob/main/2_Typecasting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = 5
a
# Out:
# 5

# %%
type(a)
# Out:
# int

# %%
b = 5.6
type(b)
# Out:
# float

# %%
a = 'Ajay'
type(a)
# Out:
# str

# %%
2+3
# Out:
# 5

# %%
type("2")
# Out:
# str

# %%
"2" + 3 #it will throw an error
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 "2" + 3
#
# TypeError: can only concatenate str (not "int") to str

# %%
#Type casting/type conversion>> The preocess of changing the data type of a value/object
#why?while executing/computation using operators, there can be mismatch between the datatype

# %%
a = "2"
b = 3
a+b
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 3
#       1 a = "2"
#       2 b = 3
# ----> 3 a+b
#
# TypeError: can only concatenate str (not "int") to str

# %%
type(a)
# Out:
# str

# %%
a = "2"
b = 3
int(a)+b
# Out:
# 5

# %%
#string to integer
a = "2"
print(type(a))
print(type(int(a)))
# Out:
# <class 'str'>
# <class 'int'>

# %%
#float to integer
a = 3.4
type(a)
# Out:
# float

# %%
a
# Out:
# 3.4

# %%
int(a)
# Out:
# 3

# %%
b = 6.78
type(b)
float_value = int(b)
type(float_value)
# Out:
# int

# %%
#integer to float
a = 2
type(a)
# Out:
# int

# %%
b = float(a)
b
# Out:
# 2.0

# %%
type(b)
# Out:
# float

# %%
#string to float
a = "2.3"
type(a)
# Out:
# str

# %%
b = float(a)
type(b)
# Out:
# float

# %%
a = "Ajay" #character cannot be converted into numbers
type(a)
# Out:
# str

# %%
int(a)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 int(a)
#
# ValueError: invalid literal for int() with base 10: 'Ajay'

# %%
float(a)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 float(a)
#
# ValueError: could not convert string to float: 'Ajay'

# %%
#integer to string
a = 5
type(a)
# Out:
# int

# %%
a
# Out:
# 5

# %%
c = str(a)

# %%
c
# Out:
# '5'

# %%
type(c)
# Out:
# str

# %%
#Typecasting>> implicit and explicit

# %%
#implicit typecasting >> python understand the datatype
a = 5
type(a)
# Out:
# int

# %%
2+3
# Out:
# 5

# %%
2+3.5
# Out:
# 5.5

# %%
#explicit typecasting >> convert data type using inbuilt functiond>> str, int, float, bool
a = "2"
type(a)
# Out:
# str

# %%
int(a)
# Out:
# 2

# %%
float(a)
# Out:
# 2.0

# %%
2+3
# Out:
# 5

# %%
a = "Ajay"
b = 5
a + b
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[44], line 3
#       1 a = "Ajay"
#       2 b = 5
# ----> 3 a + b
#
# TypeError: can only concatenate str (not "int") to str

# %%
a = "Ajay"
b = " Kumar Gupta"
a + b #concatenation of string>> meaning combine the string
# Out:
# 'Ajay Kumar Gupta'

# %%
"pw" + "skills"
# Out:
# 'pwskills'

# %%
"100" + " Ajay"
# Out:
# '100 Ajay'

# %%
#bool
bool(0)
# Out:
# False

# %%
bool(1)
# Out:
# True

# %%
bool(100)
# Out:
# True

# %%
bool(10000)
# Out:
# True
